# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Moving Dataset to the Local Space of Colab

# %%
# !mkdir /content/dataset

# %%
# !unzip "/content/drive/MyDrive/ADL-P02-GAN/datasets/Horse2Zebra/archive.zip" -d "/content/dataset"
# Out:
# Archive:  /content/drive/MyDrive/ADL-P02-GAN/datasets/Horse2Zebra/archive.zip
#   inflating: /content/dataset/metadata.csv
#   inflating: /content/dataset/testA/n02381460_1000.jpg
#   inflating: /content/dataset/testA/n02381460_1010.jpg
#   inflating: /content/dataset/testA/n02381460_1030.jpg
#   inflating: /content/dataset/testA/n02381460_1090.jpg
#   inflating: /content/dataset/testA/n02381460_1100.jpg
#   inflating: /content/dataset/testA/n02381460_1110.jpg
#   inflating: /content/dataset/testA/n02381460_1120.jpg
#   inflating: /content/dataset/testA/n02381460_1160.jpg
#   inflating: /content/dataset/testA/n02381460_120.jpg
#   inflating: /content/dataset/testA/n02381460_1210.jpg
#   inflating: /content/dataset/testA/n02381460_1260.jpg
#   inflating: /content/dataset/testA/n02381460_1300.jpg
#   inflating: /content/dataset/testA/n02381460_1350.jpg
#   inflating: /content/dataset/testA/n02381460_1360.jpg
#   inflating: /content/dataset/testA/n02381460_140.jpg
# ...

# %%
# !cp "/content/drive/MyDrive/ADL-P02-GAN/datasets/Horse2Zebra/preprocessed.csv" "/content/dataset/preprocessed.csv"
# !cp "/content/drive/MyDrive/ADL-P02-GAN/datasets/Horse2Zebra/preprocess.py" "/content/dataset/preprocess.py"

# %%
# !mkdir "/content/dataset/fakeA"
# !mkdir "/content/dataset/fakeB"

# %%
# !ls ./dataset
# Out:
# fakeA  metadata.csv	 preprocess.py	testB	trainB
# fakeB  preprocessed.csv  testA		trainA

# %% [markdown]
# # Training Model: Running `Train.sh`

# %%
# %cd "/content/drive/MyDrive/ADL-P02-GAN/"
# !ls .
# Out:
# /content/drive/MyDrive/ADL-P02-GAN
# checkpoints	   evaluated_images  pytorch_fid
# dataloaders	   fid.py	     reports
# datasets	   fid.sh	     selective_evaluated_images
# deeplearning	   fid_train.py      train.py
# eval.py		   fid_train.sh      train.sh
# eval_selective.py  generated_images  utils
# eval_selective.sh  nets
# eval.sh		   optim

# %%
# !bash ./train.sh
# Out:
# Training @ Epoch 0: 100% 67/67 [01:14<00:00,  1.11s/it, loss_cycle=0.264, loss_disc=0.375, loss_gan=0.574, loss_gen=3.212, loss_identity=0.652, lr=2.00000e-04]
# Training @ Epoch 1: 100% 67/67 [01:14<00:00,  1.12s/it, loss_cycle=0.283, loss_disc=0.306, loss_gan=0.399, loss_gen=3.231, loss_identity=0.683, lr=2.00000e-04]
# Training @ Epoch 2: 100% 67/67 [01:14<00:00,  1.11s/it, loss_cycle=0.224, loss_disc=0.223, loss_gan=0.439, loss_gen=2.676, loss_identity=0.669, lr=2.00000e-04]
# Training @ Epoch 3: 100% 67/67 [01:13<00:00,  1.10s/it, loss_cycle=0.213, loss_disc=0.232, loss_gan=0.421, loss_gen=2.553, loss_identity=0.650, lr=2.00000e-04]
# Training @ Epoch 4: 100% 67/67 [01:14<00:00,  1.11s/it, loss_cycle=0.204, loss_disc=0.225, loss_gan=0.434, loss_gen=2.471, loss_identity=0.687, lr=2.00000e-04]
# Training @ Epoch 5: 100% 67/67 [01:14<00:00,  1.11s/it, loss_cycle=0.234, loss_disc=0.190, loss_gan=0.386, loss_gen=2.727, loss_identity=0.764, lr=2.00000e-04]
# ...

# %% [markdown]
# # Evaluating Model: Running `eval.sh`

# %%
# %cd "/content/drive/MyDrive/ADL-P02-GAN/"
# !ls .
# Out:
# /content/drive/MyDrive/ADL-P02-GAN
# checkpoints	   evaluated_images  pytorch_fid
# dataloaders	   fid.py	     reports
# datasets	   fid.sh	     reports_128_r9
# deeplearning	   fid_train.py      selective_evaluated_images
# eval.py		   fid_train.sh      train.py
# eval_selective.py  generated_images  train.sh
# eval_selective.sh  nets		     utils
# eval.sh		   optim

# %%
# !bash ./eval.sh
# Out:
# Evaluation of Generators: 100% 18/18 [00:05<00:00,  3.47it/s]

# %%
# !ls ./checkpoints/
# Out:
# ckpt_disc_x_0.ckpt	ckpt_disc_y_160.ckpt	ckpt_gen_x2y_60.ckpt
# ckpt_disc_x_100.ckpt	ckpt_disc_y_180.ckpt	ckpt_gen_x2y_80.ckpt
# ckpt_disc_x_120.ckpt	ckpt_disc_y_20.ckpt	ckpt_gen_x2y_final.ckpt
# ckpt_disc_x_140.ckpt	ckpt_disc_y_40.ckpt	ckpt_gen_y2x_0.ckpt
# ckpt_disc_x_160.ckpt	ckpt_disc_y_60.ckpt	ckpt_gen_y2x_100.ckpt
# ckpt_disc_x_180.ckpt	ckpt_disc_y_80.ckpt	ckpt_gen_y2x_120.ckpt
# ckpt_disc_x_20.ckpt	ckpt_disc_y_final.ckpt	ckpt_gen_y2x_140.ckpt
# ckpt_disc_x_40.ckpt	ckpt_gen_x2y_0.ckpt	ckpt_gen_y2x_160.ckpt
# ckpt_disc_x_60.ckpt	ckpt_gen_x2y_100.ckpt	ckpt_gen_y2x_180.ckpt
# ckpt_disc_x_80.ckpt	ckpt_gen_x2y_120.ckpt	ckpt_gen_y2x_20.ckpt
# ckpt_disc_x_final.ckpt	ckpt_gen_x2y_140.ckpt	ckpt_gen_y2x_40.ckpt
# ckpt_disc_y_0.ckpt	ckpt_gen_x2y_160.ckpt	ckpt_gen_y2x_60.ckpt
# ckpt_disc_y_100.ckpt	ckpt_gen_x2y_180.ckpt	ckpt_gen_y2x_80.ckpt
# ckpt_disc_y_120.ckpt	ckpt_gen_x2y_20.ckpt	ckpt_gen_y2x_final.ckpt
# ckpt_disc_y_140.ckpt	ckpt_gen_x2y_40.ckpt

# %% [markdown]
# # Selective Evaluation

# %%
# %cd "/content/drive/MyDrive/ADL-P02-GAN/"
# !ls .
# Out:
# /content/drive/MyDrive/ADL-P02-GAN
# checkpoints		      fid_train.sh
# checkpoints_128_r9_identity0  generated_images
# dataloaders		      nets
# datasets		      optim
# deeplearning		      pytorch_fid
# eval.py			      reports
# eval_selective.py	      reports_128_r9
# eval_selective.sh	      selective_evaluated_images
# eval.sh			      selective_evaluated_images_128_r9_identity5
# evaluated_images	      train.py
# fid.py			      train.sh
# fid.sh			      utils
# fid_train.py

# %%
# !bash ./eval_selective.sh
# Out:
# Evaluation of Generators: 100% 2/2 [00:00<00:00,  3.97it/s]

# %% [markdown]
# # Calculating FID Score for Validation Data

# %%
# %cd "/content/drive/MyDrive/ADL-P02-GAN/"
# !ls .
# Out:
# /content/drive/MyDrive/ADL-P02-GAN
# checkpoints		      fid_train.sh
# checkpoints_128_r9_identity0  generated_images
# dataloaders		      nets
# datasets		      optim
# deeplearning		      pytorch_fid
# eval.py			      reports
# eval_selective.py	      reports_128_r9
# eval_selective.sh	      selective_evaluated_images
# eval.sh			      selective_evaluated_images_128_r9_identity5
# evaluated_images	      train.py
# fid.py			      train.sh
# fid.sh			      utils
# fid_train.py

# %%
# !bash ./fid_train.sh
# Out:
# Epoch 0 (Saving Fake Images): 100% 267/267 [00:07<00:00, 33.62it/s]
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:02<00:00, 38.4MB/s]
# 100% 15/15 [00:00<00:00, 20.53it/s]
# 100% 34/34 [00:01<00:00, 30.46it/s]
# 100% 18/18 [00:00<00:00, 21.49it/s]
# 100% 34/34 [00:01<00:00, 30.25it/s]
# Epoch 20 (Saving Fake Images): 100% 267/267 [00:07<00:00, 35.39it/s]
# 100% 15/15 [00:00<00:00, 20.58it/s]
# 100% 34/34 [00:01<00:00, 29.58it/s]
# 100% 18/18 [00:00<00:00, 21.66it/s]
# 100% 34/34 [00:01<00:00, 30.42it/s]
# Epoch 40 (Saving Fake Images): 100% 267/267 [00:07<00:00, 34.95it/s]
# 100% 15/15 [00:00<00:00, 20.42it/s]
# 100% 34/34 [00:01<00:00, 30.23it/s]
# 100% 18/18 [00:00<00:00, 21.11it/s]
# 100% 34/34 [00:01<00:00, 30.84it/s]
# Epoch 60 (Saving Fake Images): 100% 267/267 [00:07<00:00, 34.46it/s]
# ...

# %% [markdown]
# # Calculating FID Score for Test Set

# %%
# %cd "/content/drive/MyDrive/ADL-P02-GAN/"
# !ls .
# Out:
# /content/drive/MyDrive/ADL-P02-GAN
# checkpoints	    deeplearning      fid.py	    generated_images  reports
# checkpoints_128_r9  eval.py	      fid.sh	    nets	      train.py
# dataloaders	    eval.sh	      fid_train.py  optim	      train.sh
# datasets	    evaluated_images  fid_train.sh  pytorch_fid       utils

# %%
# !bash ./fid.sh
# Out:
# Saving Fake Images: 100% 140/140 [00:03<00:00, 43.97it/s]
# 100% 15/15 [00:00<00:00, 24.30it/s]
# 100% 18/18 [00:00<00:00, 32.65it/s]
# 100% 18/18 [00:00<00:00, 25.63it/s]
# 100% 18/18 [00:00<00:00, 30.95it/s]
# FID -> X: 317.13586244021064, Y: 383.43666929857227
